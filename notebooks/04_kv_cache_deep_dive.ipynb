# %% [markdown]
# # 04 kv cache deep dive
#
# This notebook provides analysis for 04 kv cache deep dive.

# %%
import sys
sys.path.insert(0, '..')

# Import benchmark modules
from benchmark.runner import BenchmarkRunner
from analysis.plots import PlotGenerator

# %% [markdown]
# ## Setup and Configuration

# %%
# Configuration for this analysis
print('Notebook ready for analysis')
